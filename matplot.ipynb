# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
matplotlib inline # all the graph should keep inside the line

# %%
from PIL import Image # python imaging library

# %%
project_img= Image.open(r'C:\Users\ky321\OneDrive\Pictures\project.jpg')
project_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=650x650>

# %%
type(project_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
project_img_arr=np.asarray(project_img)
project_img_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
type(project_img_arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(project_img_arr)

# %%
project_img_arr.shape
# Out:
# (650, 650, 3)

# %%
project_img_copy = np.copy(project_img_arr)
project_img_copy
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
project_img_copy.shape
# Out:
# (650, 650, 3)

# %%
plt.imshow(project_img_copy[:,:,0])

# %%
plt.imshow(project_img_copy[:,:,0],cmap='Greys')

# %%
plt.imshow(project_img_copy[:,:,0],cmap='Purples')
